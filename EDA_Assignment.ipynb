# %% [markdown]
# #**EDA Assignment (EDA 1 Assignment Questions & Answers):**
#
#
#
# 1.**What is the range of selling prices in the dataset?**
#
# Ans: The range of selling prices is calculated as:
# Range = Maximum selling_price - Minimum selling_price
#
# 2.**What is the median selling price for bikes in the dataset?**
#
# Ans: The median is the middle value of the selling_price column after sorting.
# Use: df['selling_price'].median()
#
# 3.**What is the most common seller type?**
#
# Ans: Use mode() or value_counts() to find the most frequent seller type.
# E.g., 'Individual' or 'Dealer'.
#
# 4.**How many bikes have driven more than 50,000 kilometers?**
#
# Ans: Count of records where km_driven > 50000.
# Use: df[df['km_driven'] > 50000].shape[0]
#
# 5.**What is the average km_driven value for each ownership type?**
#
# Ans: Group by owner and calculate mean of km_driven:
# df.groupby('owner')['km_driven'].mean()
#
# 6.**What proportion of bikes are from the year 2015 or older?**
#
# Ans: Use: len(df[df['year'] <= 2015]) / len(df)
#
# 7.**What is the trend of missing values across the dataset?**
#
# Ans: Check missing values with:
# df.isnull().sum()
#
# 8.**What is the highest ex_showroom_price recorded, and for which bike?**
#
# Ans: Use: df[df['ex_showroom_price'] == df['ex_showroom_price'].max()]
#
# 9.**What is the total number of bikes listed by each seller type?**
#
# Ans: Use: df['seller_type'].value_counts()
#
# 10.**What is the relationship between selling_price and km_driven for first-owner bikes?**
#
# Ans: Filter first owners and use correlation or scatterplot:
# sns.scatterplot(data=first_owner_df, x='km_driven', y='selling_price')
#
# 11.**Identify and remove outliers in the km_driven column using the IQR method.**
#
# Ans: Use: Q1 = df['km_driven'].quantile(0.25)
# Q3 = df['km_driven'].quantile(0.75)
# IQR = Q3 - Q1 df_filtered = df[(df['km_driven'] >= Q1 - 1.5*IQR) & (df['km_driven'] <= Q3 + 1.5*IQR)]
#
# 12.**Perform a bivariate analysis to visualize the relationship between year and selling_price.**
#
# Ans: Use scatter plot or box plot:
# sns.boxplot(x='year', y='selling_price', data=df)
#
# 13.**What is the average depreciation in selling price based on the bike's age?**
#
# Ans: df['age'] = 2025 - df['year']
# df.groupby('age')['selling_price'].mean()
#
# 14.**Which bike names are priced significantly above the average price for their
# manufacturing year?**
#
# Ans: Compare each bike's price with the average for that year and flag outliers:
# df['above_avg'] = df.groupby('year')['selling_price'].transform(lambda x: x > x.mean())
#
# 15.**Develop a correlation matrix for numeric columns and visualize it using a heatmap.**
#
# Ans: corr = df.corr(numeric_only=True)
# sns.heatmap(corr, annot=True, cmap='coolwarm')

# %% [markdown]
# #**EDA Assignment (EDA 2 Assignment Questions & Answers):**
#
#
#
# 1.**What is the average selling price of cars for each dealer, and how does it compare across different dealers?**
#
# Ans: This can be determined by grouping the dataset by dealer and calculating the average selling price for each. Comparing these averages shows pricing differences among dealers.
#
# 2.**Which car brand (Company) has the highest variation in prices, and what does this tell us about the pricing trends?**
#
# Ans: By calculating the standard deviation of prices within each car brand, we can identify which brand has the highest variation, indicating either a broad product range or inconsistent pricing.
#
# 3.**What is the distribution of car prices for each transmission type, and how do the interquartile ranges compare?**
#
# Ans: Boxplots can be used to visualize this. Comparing the interquartile range reveals variability in price within each transmission type.
#
# 4.**What is the distribution of car prices across different regions?**
#
# Ans: Grouping by region and plotting histograms or boxplots reveals how prices vary across geographic locations.
#
# 5.**What is the distribution of cars based on body styles?**
#
# Ans: A simple count plot of the 'Body Style' column will show the frequency of each style like Sedan, SUV, etc.
#
# 6.**How does the average selling price of cars vary by customer gender and annual income?**
#
# Ans: Grouping the data by gender and analyzing income brackets with average car prices will reveal any price differences.
#
# 7.**What is the distribution of car prices by region, and how does the number of cars sold vary by region?**
#
# Ans: Use bar charts for car counts and boxplots for price distributions across regions.
#
# 8.**How does the average car price differ between cars with different engine sizes?**
#
# Ans: Grouping by engine size and computing average price gives insight into how engine type affects value.
#
# 9.**How do car prices vary based on the customer's annual income bracket?**
#
# Ans: Bin the income data into ranges and analyze the average selling price for each bracket.
#
# 10.**What are the top 5 car models with the highest number of sales, and how does their price distribution look?**
#
# Ans: Count the occurrences of each model and review the price distributions of the top 5 using boxplots.
#
# 11.**How does car price vary with engine size across different car colors, and which colors have the highest price variation?**
#
# Ans: Grouping by both engine size and color, then calculating price stats, reveals the patterns.
#
# 12.**Is there any seasonal trend in car sales based on the date of sale?**
#
# Ans: Extract month from the sale date and count the number of sales per month to observe
# seasonal trends.
#
# 13.**How does the car price distribution change when considering different combinations of body style and transmission type?**
#
# Ans: A multi-level groupby or faceted plots can show how combinations affect price distributions.
#
# 14.**What is the correlation between car price, engine size, and annual income of customers, and how do these features interact?**
#
# Ans: Correlation matrices or scatter plots with regression lines help visualize interactions between these variables.
#
# 15.**How does the average car price vary across different car models and engine types?**
#
# Ans: Group the data by model and engine type, then compute the mean price for each group.

# %% [markdown]
# #**EDA Assignment (EDA 3 Assignment Questions & Answers):**
#
#
#
# 1.**What is the average rating for each product category?**
#
# Ans: Group the data by 'category' and compute the average of the 'rating' column.
#
# 2.**What are the top rating_count products by category?**
#
# Ans:Sort the dataset within each 'category' by 'rating_count' in descending order to find the most rated products.
#
# 3.**What is the distribution of discounted prices vs. actual prices?**
#
# Ans: Visualize using histograms or KDE plots to compare the distributions of 'discounted_price' and 'actual_price'.
#
# 4.**How does the average discount percentage vary across categories?**
#
# Ans: Group the data by 'category' and calculate the mean 'discount_percentage'.
#
# 5.**What are the most popular product names?**
#
# Ans: Use frequency counts of 'product_name' to find the most common products.
#
# 6.**What are the most popular product keywords?**
#
# Ans: Extract keywords from 'product_name' or 'about_product' using NLP and rank by frequency.
#
# 7.**What are the most popular product reviews?**
#
# Ans: Identify reviews with high engagement, or apply sentiment analysis to 'review_content'.
#
# 8.**What is the correlation between discounted_price and rating?**
#
# Ans: Use '.corr()' or a scatter plot to observe relationships between 'discounted_price' and 'rating'.
#
# 9.**What are the Top 5 categories based on the highest ratings?**
#
# Ans: Calculate the average 'rating' per 'category', then select the top 5.
#
# 10.**Identify any potential areas for improvement or optimization based on the data analysis.**
#
# Ans: Categories with low average ratings but high 'rating_count' may need product quality reviews. Price optimization may help if discounting doesn't improve ratings.

# %% [markdown]
# #**EDA Assignment (EDA 4 Assignment Questions & Answers):**
#
#
#
# 1.**Read the dataframe, check null value if present then do the needful, check duplicate row, if present then do the needful.**
#
# Ans:
# - Load using pd.read_csv()
# - Check nulls: df.isnull().sum()
# - Drop/fill nulls
# - Check duplicates: df.duplicated().sum()
# - Drop duplicates: df.drop_duplicates()
#
# 2.**What is the distribution of popularity among the tracks in the dataset? Visualize it using a histogram.**
#
# Ans:
# - Use: sns.histplot(df['popularity'])
# - Most tracks have moderate popularity.
#
# 3.**Is there any relationship between the popularity and the duration of tracks? Explore this using a scatter plot.**
#
# Ans:
# - Use: sns.scatterplot(x='duration_ms', y='popularity', data=df)
# - Little to no strong correlation.
#
# 4.**Which artist has the highest number of tracks in the dataset? Display the count of tracks for each artist using a countplot.**
#
# Ans:
# - Use: df['artist'].value_counts().idxmax()
# - Visualize: sns.countplot(y='artist', order=df['artist'].value_counts().head(10).index)
#
# 5.**What are the top 5 least popular tracks in the dataset? Provide the artist name and track name for each.**
#
# Ans:
# Code: df.nsmallest(5, 'popularity')[['artist', 'track_name']]
#
# 6.**Among the top 5 most popular artists, which artist has the highest popularity on average?**
#
# Ans:
# Code:
#  top_artists = df['artist'].value_counts().head(5).index
#  df[df['artist'].isin(top_artists)].groupby('artist')['popularity'].mean().sort_values(ascending=False)
#
# 7.**For the top 5 most popular artists, what are their most popular tracks?**
#
# Ans:
# Code:
#  df[df['artist'].isin(top_artists)].sort_values(['artist', 'popularity'], ascending=[True,
# False]).groupby('artist').first()
#
# 8.**Visualize relationships between multiple numerical variables simultaneously using a pair plot.**
#
# Ans:
# - Use: sns.pairplot(df[['popularity', 'duration_ms']])
#
# 9.**Does the duration of tracks vary significantly across different artists? Explore this using a box plot or violin plot.**
#
# Ans:
# - Use: sns.boxplot(x='artist', y='duration_ms', data=df)
# - Or: sns.violinplot(x='artist', y='duration_ms', data=df)
#
# 10.**How does the distribution of track popularity vary for different artists? Visualize using a swarm plot or violin plot.**
#
# Ans:
# - Use: sns.violinplot(x='artist', y='popularity', data=df)
# - Or: sns.swarmplot(x='artist', y='popularity', data=df)
